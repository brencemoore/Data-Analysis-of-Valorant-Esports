# %%
import pandas as pd

# !gdown 1cbPFh3ZWstejb3VzHDpzw0iezuJZs1PG

data = pd.read_csv('valorant_champ_2024.csv')

data
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cbPFh3ZWstejb3VzHDpzw0iezuJZs1PG
# To: /content/valorant_champ_2024.csv
# 100% 21.0k/21.0k [00:00<00:00, 48.5MB/s]
#     Player       Team  Rating  ACS  Kills  Deaths  Assits  K/D_Difference  \
# 0      Fox      y9DRX    1.24  220     23      17      13               6
# 1      Fla  shbackDRX    1.15  220     22      18       4               4
# 2      BeY       NDRX    0.97  172     18      20       5              -2
# 3      BuZ       zDRX    0.73  197     18      22      10              -4
# 4      MaK       oDRX    0.72  163     13      21      11              -8
# ..     ...        ...     ...  ...    ...     ...     ...             ...
# 375    ben  jyfishyTH    1.11  224     17      16       6               1
# 376    Wo0        tTH    0.95  206     15      18       6              -3
# 377    Rie       NsTH    0.79  173     11      17       5              -6
# ...

# %%
# Will add a feature that has a number for games 1-38 so that an average for that map can be taken
